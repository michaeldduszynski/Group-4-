# %%
import gmaps
import os
import csv

# Google developer API key
from config import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

# %%
import gmaps

# Google developer API key
from config import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)

# %%
zipcodes = []
latList = []
longList = []
redLightLoc = os.path.join("..", "Group-4-", "Red_Zip_LL.csv")

with open(redLightLoc, 'r', encoding='utf-8') as csvfile:
    csvreader = csv.reader(csvfile, delimiter=',')
    header = next(csvreader)
    for row in csvreader:
        zipcode = row[1]
        latitude = row[2]
        longitude = row[3]
        zipcodes.append(zipcode)
        latList.append(latitude)
        longList.append(longitude)

#converting str into floats
f_lat = []
for item in latList:
    f_lat.append(float(item))

f_long = []
for item in longList:
    f_long.append(float(item))

# %%
coordList = []       
###coordList = [(latitude, longitude) for i in latList]
coordList = list(zip(f_lat, f_long))
coordList
# Out:
# [(41.990442, -87.699401),
#  (41.945877, -87.766754),
#  (41.779214, -87.683638),
#  (41.750643, -87.644043),
#  (41.8857, -87.637),
#  (41.924106, -87.756147),
#  (41.736271, -87.625445),
#  (41.867252, -87.639216),
#  (41.924484, -87.726769),
#  (41.77334, -87.586295),
#  (41.91032, -87.687222),
#  (41.765868, -87.605586),
#  (41.794201, -87.630518),
#  (41.780058, -87.625374),
#  (41.903347, -87.667496),
#  (41.924237, -87.746302),
#  (41.881815, -87.745339),
#  (41.895591, -87.702455),
#  (41.92398, -87.765989),
#  (41.968614, -87.688906),
#  (41.953646, -87.727617),
#  (41.917402, -87.706965),
#  (41.931533, -87.746595),
#  (41.960632, -87.754476),
#  (41.932179, -87.687883),
#  (41.9249, -87.687641),
#  (41.931984, -87.712251),
#  (41.844518, -87.705042),
#  (41.735788, -87.663063),
#  (41.931791, -87.726979),
#  (41.778972, -87.703138),
#  (41.893268, -87.624038),
#  (41.852031, -87.685639),
#  (41.976396, -87.654993),
#  (41.939094, -87.727185),
#  (41.909886, -87.72633),
# ...

# %%
figure_layout = {
    'width': '1800px',
    'height': '1600px',
    'border': '2px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
my_points = gmaps.marker_layer(coordList)
# Add the layer to the map
fig.add_layer(my_points)
fig
# Out:
# Figure(layout=FigureLayout(border='2px solid black', height='1600px', margin='0 auto 0 auto', padding='1px', w…
